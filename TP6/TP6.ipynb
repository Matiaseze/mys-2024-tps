# %%
from autopartes import *


simulacion()
# Out:
# Umbral de inventario: 50
# Promedio de turnos adicionales: 39.03
# IC 95% turnos adicionales: (38.01, 40.06)
# Promedio de costos anuales de mantenimiento: 2096154.33
# IC 95% costos anuales: (2074859.76, 2117448.89)
# Umbral de inventario: 60
# Promedio de turnos adicionales: 39.00
# IC 95% turnos adicionales: (38.35, 39.65)
# Promedio de costos anuales de mantenimiento: 2191657.73
# IC 95% costos anuales: (2162545.20, 2220770.27)
# Umbral de inventario: 70
# Promedio de turnos adicionales: 38.96
# IC 95% turnos adicionales: (38.43, 39.48)
# Promedio de costos anuales de mantenimiento: 2278367.23
# IC 95% costos anuales: (2245782.24, 2310952.21)
# Umbral de inventario: 80
# Promedio de turnos adicionales: 38.85
# IC 95% turnos adicionales: (38.38, 39.32)
# Promedio de costos anuales de mantenimiento: 2372090.84
# IC 95% costos anuales: (2333755.88, 2410425.80)
