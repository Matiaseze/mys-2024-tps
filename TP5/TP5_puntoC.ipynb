# %% [markdown]
# # Modelos y Simulación
#
# ## Trabajo Práctico N°5:
# ## Simulación de Proyectos
#
# ### Alumno: Barea Matias
#
# ### Profesores: Lic. Claudia López de Munain - Lic. Bruno Alfredo Pazos

# %% [markdown]
# c. Simule 30 experimentos de 100 corridas cada una y calcule:
# El tiempo promedio de finalización del proyecto y el IC. Con el 99% de probabilidad (2,57).
# Calcule el porcentaje de criticidad tienen los diferentes accesos. En el caso del ejercicio 3, evalúe el porcentaje de criticidad de cada tarea.
# Grafique un histograma con la distribución del tiempo de realización del proyecto con los datos de las 3000 corridas. Y otro teniendo en cuenta los promedios de los 30 experimentos.

# %%
num_experimentos = 30
num_corridas = 100

# %% [markdown]
# ## Hotel

# %%
from hotel import *

tiempos_experimentos = []
tiempo_proyecto = []
criticidad_accesos_experimentos = []

# 1.
tiempos_experimentos, tiempo_proyecto, criticidad_accesos_experimentos = simular_proyecto(num_experimentos, num_corridas)
ic_99_inf, ic_99_sup = calcular_ic99_exp(tiempos_experimentos)

print("Intervalo de confianza inf:", ic_99_inf)
print("Intervalo de confianza sup:",ic_99_sup )
# Out:
# Tiempo promedio de finalización del proyecto: 11.859297964174687
# Intervalo de confianza inf: 11.451581529862159
# Intervalo de confianza sup: 12.267014398487214

# %%
# 2.
total_corridas = num_experimentos * num_corridas
calcular_criticidad_accesos(total_corridas, criticidad_accesos_experimentos)
# Out:
# Porcentaje de criticidad para acceso superior : 98.5
# Porcentaje de criticidad para acceso medio : 2.8000000000000003
# Porcentaje de criticidad para acceso inferior : 98.7

# %%
# 3.
graficar_histogramas(tiempo_proyecto, tiempos_experimentos)

# %% [markdown]
# ## Lavadero

# %%
from lavadero import *

tiempos_experimentos = []
tiempo_proyecto = []
criticidad_accesos_experimentos = []

# 1.
tiempos_experimentos, tiempo_proyecto, criticidad_accesos_experimentos = simular_proyecto(num_experimentos, num_corridas)
ic_99_inf, ic_99_sup = calcular_ic99_exp(tiempos_experimentos)

print("Intervalo de confianza inf:", ic_99_inf)
print("Intervalo de confianza sup:",ic_99_sup )
# Out:
# Tiempo promedio de finalización del proyecto: 32.51605164531986
# Intervalo de confianza inf: 31.503812513199474
# Intervalo de confianza sup: 33.528290777440255

# %%
# 2.
total_corridas = num_experimentos * num_corridas
calcular_criticidad_accesos(total_corridas, criticidad_accesos_experimentos)
# Out:
# Porcentaje de criticidad para acceso superior : 0.0
# Porcentaje de criticidad para acceso inferior : 0.0
# Porcentaje de criticidad para acceso infcong : 200.0

# %%
# 3.
graficar_histogramas(tiempo_proyecto, tiempos_experimentos)

# %% [markdown]
# ## Constructora

# %%
from constructora import *

tiempos_experimentos = []
tiempo_proyecto = []
criticidad_accesos_experimentos = []

# 1.
tiempos_experimentos, tiempo_proyecto, criticidad_accesos_experimentos = simular_proyecto(num_experimentos, num_corridas)
ic_99_inf, ic_99_sup = calcular_ic99_exp(tiempos_experimentos)

print("Intervalo de confianza inf:", ic_99_inf)
print("Intervalo de confianza sup:",ic_99_sup )
# Out:
# Tiempo promedio de finalización del proyecto: 23.589337768921453
# Intervalo de confianza inf: 23.00927185121826
# Intervalo de confianza sup: 24.169403686624648

# %%
# 2.
total_corridas = num_experimentos * num_corridas
calcular_criticidad_accesos(total_corridas, criticidad_accesos_experimentos)
# Out:
# Porcentaje de criticidad para acceso inicial : 1701.697587197583
# Porcentaje de criticidad para acceso superior : 2197.147020626473
# Porcentaje de criticidad para acceso medio : 2098.420026742606
# Porcentaje de criticidad para acceso inferior : 2495.2038015838266
# Porcentaje de criticidad para acceso final : 499.4607565605525

# %%
# 3.
graficar_histogramas(tiempo_proyecto, tiempos_experimentos)
